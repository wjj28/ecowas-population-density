# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import numpy as np
import csv

# %%
population = pd.read_csv('doc.csv')

# %%
population.head()
# Out:
#                   Country Name Country Code     Indicator Name Indicator Code  \
# 0                        Aruba          ABW  Population, total    SP.POP.TOTL
# 1  Africa Eastern and Southern          AFE  Population, total    SP.POP.TOTL
# 2                  Afghanistan          AFG  Population, total    SP.POP.TOTL
# 3   Africa Western and Central          AFW  Population, total    SP.POP.TOTL
# 4                       Angola          AGO  Population, total    SP.POP.TOTL
#
#           1960         1961         1962         1963         1964  \
# 0      54208.0      55434.0      56234.0      56699.0      57029.0
# 1  130836765.0  134159786.0  137614644.0  141202036.0  144920186.0
# 2    8996967.0    9169406.0    9351442.0    9543200.0    9744772.0
# 3   96396419.0   98407221.0  100506960.0  102691339.0  104953470.0
# 4    5454938.0    5531451.0    5608499.0    5679409.0    5734995.0
#
#           1965  ...         2011         2012         2013         2014  \
# ...

# %%
population.tail()
# Out:
#      Country Name Country Code     Indicator Name Indicator Code        1960  \
# 261        Kosovo          XKX  Population, total    SP.POP.TOTL    947000.0
# 262   Yemen, Rep.          YEM  Population, total    SP.POP.TOTL   5315351.0
# 263  South Africa          ZAF  Population, total    SP.POP.TOTL  17099836.0
# 264        Zambia          ZMB  Population, total    SP.POP.TOTL   3070780.0
# 265      Zimbabwe          ZWE  Population, total    SP.POP.TOTL   3776679.0
#
#            1961        1962        1963        1964        1965  ...  \
# 261    966000.0    994000.0   1022000.0   1050000.0   1078000.0  ...
# 262   5393034.0   5473671.0   5556767.0   5641598.0   5727745.0  ...
# 263  17524533.0  17965733.0  18423157.0  18896303.0  19384838.0  ...
# 264   3164330.0   3260645.0   3360099.0   3463211.0   3570466.0  ...
# 265   3905038.0   4039209.0   4178726.0   4322854.0   4471178.0  ...
#
#            2011        2012        2013        2014        2015        2016  \
# ...

# %% [markdown]
# Deleting the columns we are not interested in

# %%
countries = population.drop(['Indicator Name','Indicator Code'],axis = 1)

# %%
countries
# Out:
#                     Country Name Country Code         1960         1961  \
# 0                          Aruba          ABW      54208.0      55434.0
# 1    Africa Eastern and Southern          AFE  130836765.0  134159786.0
# 2                    Afghanistan          AFG    8996967.0    9169406.0
# 3     Africa Western and Central          AFW   96396419.0   98407221.0
# 4                         Angola          AGO    5454938.0    5531451.0
# ..                           ...          ...          ...          ...
# 261                       Kosovo          XKX     947000.0     966000.0
# 262                  Yemen, Rep.          YEM    5315351.0    5393034.0
# 263                 South Africa          ZAF   17099836.0   17524533.0
# 264                       Zambia          ZMB    3070780.0    3164330.0
# 265                     Zimbabwe          ZWE    3776679.0    3905038.0
#
#             1962         1963         1964         1965         1966  \
# ...

# %%
cv = countries.loc[(countries['Country Code']=='Cabo Verde')]

# %%
cote_ivoire = countries.loc[(countries['Country Name'].str.startswith('G'))]

# %%
cote_ivoire
# Out:
#      Country Name Country Code        1960        1961        1962  \
# 55        Germany          DEU  72814900.0  73377632.0  74025784.0
# 80          Gabon          GAB    500922.0    505793.0    511285.0
# 82        Georgia          GEO   3645600.0   3703600.0   3760300.0
# 83          Ghana          GHA   6635229.0   6848291.0   7071966.0
# 84      Gibraltar          GIB     23420.0     23808.0     24307.0
# 85         Guinea          GIN   3494164.0   3552068.0   3611428.0
# 86    Gambia, The          GMB    365049.0    372436.0    379886.0
# 87  Guinea-Bissau          GNB    616140.0    622754.0    628877.0
# 89         Greece          GRC   8331725.0   8398050.0   8448233.0
# 90        Grenada          GRD     89927.0     91324.0     92481.0
# 91      Greenland          GRL     32500.0     33700.0     35000.0
# 92      Guatemala          GTM   4128880.0   4251911.0   4378604.0
# 93           Guam          GUM     66733.0     68065.0     69605.0
# ...

# %% [markdown]
# ### ECOWAS
# The Economic Community of West African States (ECOWAS) is made up of fifteen member countries that are located in the Western African region.

# %%
ECOWAS = ['Benin','Burkina Faso','Cabo Verde', 'Cote d\'Ivoire','Gambia, The',
         'Ghana', 'Guinea','Guinea-Bissau','Liberia','Mali','Niger','Nigeria','Senegal','Sierra Leone','Togo']

# %% [markdown]
# To make sure that every single state member of ECOWAS is in the list, and to print the ones we found

# %%
countries_name = countries['Country Name']

i = set.intersection(set(countries_name),set(ECOWAS))
if len(i)>0:
    print("duplicates found",i)
# Out:
# duplicates found {'Ghana', 'Senegal', 'Togo', 'Niger', 'Guinea-Bissau', 'Nigeria', "Cote d'Ivoire", 'Guinea', 'Benin', 'Sierra Leone', 'Gambia, The', 'Burkina Faso', 'Mali', 'Liberia', 'Cabo Verde'}

# %% [markdown]
# now we want to select only the ECOWAS state members

# %%
western_africa = (countries[countries_name.isin(ECOWAS)])

# %%
western_africa
# Out:
#       Country Name Country Code        1960        1961        1962  \
# 18           Benin          BEN   2431617.0   2465865.0   2502897.0
# 19    Burkina Faso          BFA   4829289.0   4894580.0   4960328.0
# 41   Cote d'Ivoire          CIV   3503559.0   3631547.0   3770756.0
# 47      Cabo Verde          CPV    201770.0    205321.0    210141.0
# 83           Ghana          GHA   6635229.0   6848291.0   7071966.0
# 85          Guinea          GIN   3494164.0   3552068.0   3611428.0
# 86     Gambia, The          GMB    365049.0    372436.0    379886.0
# 87   Guinea-Bissau          GNB    616140.0    622754.0    628877.0
# 131        Liberia          LBR   1118655.0   1142304.0   1166651.0
# 158           Mali          MLI   5263727.0   5322269.0   5381367.0
# 173          Niger          NER   3388774.0   3486322.0   3588228.0
# 174        Nigeria          NGA  45138460.0  46063570.0  47029818.0
# 207        Senegal          SEN   3206757.0   3295280.0   3386803.0
# ...

# %%
top10 = western_africa.sort_values('2020', ascending = True).head(15)
plt.xticks(rotation = '45')
plt.title('Population Density of ECOWAS members for the year 2020', color = 'r')
plt.rcParams['figure.figsize'] = (15, 15)
plt.rcParams['font.size'] = 15
plt.xlabel('Countries', color = 'r')
plt.ylabel('Population Density', color = 'g')
plt.bar(top10['Country Code'],
        top10['2020'],
        color = cm.rainbow(np.linspace(0, 1, len(top10))))
# Out:
# <BarContainer object of 15 artists>

# %%
countries = western_africa['Country Name']
populationDensity2020 = western_africa['2020']
plt.rcParams['figure.figsize'] = (20, 20)
plt.rcParams['font.size'] = 20
plt.xticks(rotation = '90')
plt.bar(countries, populationDensity2020, color = cm.rainbow(np.linspace(0, 1, len(countries))))
# Out:
# <BarContainer object of 15 artists>

# %% [markdown]
# # Range of Population Density for the years 1962-2020
#  Population density data can be used to quantify demographic information and to assess relationships with ecosystems, human health, and infrastructure.

# %%
minimum = western_africa.loc[:, western_africa.columns != 'Country Name'].min()
maximum = western_africa.loc[:, western_africa.columns != 'Country Name'].max()
diff = maximum[1:] - minimum[1:]
minOfMax = maximum[1:].min()
plt.title('Range of Population Density for the years 1962-2020', color ='g')
plt.rcParams['figure.figsize'] = (15, 20)
plt.rcParams['font.size'] = 20
plt.xticks(rotation = '90')
plt.xlabel('Years', color='g')
plt.ylabel('Population Density', color = 'g')
plt.bar(western_africa.columns[2:], diff.apply(lambda x: x-minOfMax), color = cm.rainbow(np.linspace(0, 1, western_africa.shape[1])))
# Out:
# <BarContainer object of 61 artists>
